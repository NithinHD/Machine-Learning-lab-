# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
names=['KNeighborsClassifier','SVC','MLPClassifier','GaussianNB','DecisionTreeClassifier']
classifiers=[KNeighborsClassifier(3),
             SVC(kernel='linear',C=0.025),
             MLPClassifier(max_iter=1000),
             GaussianNB(),
             DecisionTreeClassifier(max_depth=5)]

# %%
df=pd.read_csv('Iris.csv')

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df=df.drop('Id',axis=1)

# %%
y=df['Species'] 
X=df.drop('Species',axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)
y=pd.DataFrame(y)
y
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 145  2
# 146  2
# 147  2
# 148  2
# 149  2
#
# [150 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train.values.ravel())
    score = clf.score(X_test, y_test)
    print(name, score)
# Out:
# KNeighborsClassifier 0.9555555555555556
# SVC 0.8888888888888888
# MLPClassifier 0.9777777777777777
# GaussianNB 0.9111111111111111
# DecisionTreeClassifier 0.9333333333333333
