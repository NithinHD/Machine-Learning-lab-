# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read csv file
df=pd.read_csv('Salary.csv')
print(df.to_string)
# Out:
# <bound method DataFrame.to_string of     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.2  127345
# 31             11.5  126756
# 32             12.3  128765
# 33             12.9  135675
# 34             13.5  139465>

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
#feature years of experience
x=df.iloc[:,:-1].values

#feature salary
y=df.iloc[:,-1].values
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5],
#        [11.2],
#        [11.5],
#        [12.3],
#        [12.9],
#        [13.5]])

# %%
y
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872, 127345, 126756,
#        128765, 135675, 139465])

# %%
from sklearn.model_selection import train_test_split

# %%
#splitting the data into training and testing data
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3)

# %%
#imprt linear regression model
from sklearn.linear_model import LinearRegression

model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#predicting the test set results
prediction=model.predict(X_test)
prediction
# Out:
# array([ 50036.76805295,  40825.10971893, 112006.10593631, 119542.91730051,
#        117868.07033069,  65110.39078133,  64272.96729642,  65947.81426624,
#         91070.51881355,  69297.50820588, 111168.6824514 ])

# %%
plt.scatter(X_train,Y_train,color='red')
plt.plot(X_train,model.predict(X_train),color='pink')

# %%
#visualizing the test set results
r_sq=model.score(X_train,Y_train)
print('coefficient of determination:',r_sq)
# Out:
# coefficient of determination: 0.9637706534305179

# %%
#print the intercept
print('intercept:',model.intercept_)
# Out:
# intercept: 31613.451384918524

# %%
#print the slope
print('slope:',model.coef_)
# Out:
# slope: [8374.2348491]

# %%
#predicting the test set results
y_pred=model.predict(X_test)
print('predicted response:',y_pred)
print('y=',(model.coef_),'x=',((model.intercept_)))
# Out:
# predicted response: [ 50036.76805295  40825.10971893 112006.10593631 119542.91730051
#  117868.07033069  65110.39078133  64272.96729642  65947.81426624
#   91070.51881355  69297.50820588 111168.6824514 ]
# y= [8374.2348491] x= 31613.451384918524
