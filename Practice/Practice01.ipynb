# %%
import pandas as pd
fd=pd.read_csv("diabetes.csv")
print(fd)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
people={
    "first":["mohan","james","swara"],
    "last":["rao","nick","laasya"],
    "email":["mohanrrao@gmail.com","jamesnic@gmail.com","swaralaasya@gmail.com"]
}

# %%
people
type(people)
# Out:
# dict

# %%
df=pd.DataFrame(people)

# %%
df.email
# Out:
# 0      mohanrrao@gmail.com
# 1       jamesnic@gmail.com
# 2    swaralaasya@gmail.com
# Name: email, dtype: object

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df
# Out:
#    first    last                  email
# 0  mohan     rao    mohanrrao@gmail.com
# 1  james    nick     jamesnic@gmail.com
# 2  swara  laasya  swaralaasya@gmail.com

# %%
# iloc - index location
df.iloc[0]
# Out:
# first                  mohan
# last                     rao
# email    mohanrrao@gmail.com
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# first                 james
# last                   nick
# email    jamesnic@gmail.com
# Name: 1, dtype: object

# %%
df.iloc[0,1]
# Out:
# 'rao'

# %%
df.iloc[[0,1],[1,2]]
# Out:
#    last                email
# 0   rao  mohanrrao@gmail.com
# 1  nick   jamesnic@gmail.com

# %%
df.reset_index(inplace=True)

# %%
df.set_index["email",inplace==True]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/nithin/Documents/GitHub/Machine-Learning-lab-/Practice/Practice01.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/Users/nithin/Documents/GitHub/Machine-Learning-lab-/Practice/Practice01.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> df.set_index["email",inplace==True]
#
# NameError: name 'inplace' is not defined
